# %% [markdown]
# # Регрессионный анализ

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
data = pd.read_csv("cirrhosis.csv")
data
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df = data.copy()

#Целевой признак
target = 'Bilirubin'

#Первичный сброс пустых значений
df = df[df[target].notna()]


numeric_features = ['Age', 'Albumin', 'Copper', 'Alk_Phos', 'SGOT',
                    'Tryglicerides', 'Platelets', 'Prothrombin', 'Cholesterol']

 #Кодирование категориальных признаков
categorical_features = ['Sex', 'Ascites', 'Hepatomegaly', 'Spiders', 'Edema', 'Drug', 'Status']
df.dropna(subset=['Drug'], inplace=True)

for col in categorical_features:
    if col in df.columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
#Замена пустых числовых значений на моду
df.Cholesterol = df.Cholesterol.fillna(df.Cholesterol.median())
df.Tryglicerides = df.Tryglicerides.fillna(df.Tryglicerides.median())
df.Copper = df.Copper.fillna(df.Copper.median())
df.Platelets = df.Platelets.fillna(df.Platelets.median())
# Out:
# Размер данных после предобработки: (312, 16)

# %%
remaining_nulls = df.isnull().sum().sum()
print(f"\nОсталось пропусков после обработки: {remaining_nulls}")
df
# Out:
# Осталось пропусков после обработки: 0
#       ID  N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0      1     400       2     0  21464    0        1             1        1
# 1      2    4500       0     0  20617    0        0             1        1
# 2      3    1012       2     0  25594    1        0             0        0
# 3      4    1925       2     0  19994    0        0             1        1
# 4      5    1504       1     1  13918    0        0             1        1
# ..   ...     ...     ...   ...    ...  ...      ...           ...      ...
# 307  308    1153       0     0  22347    0        0             1        0
# 308  309     994       0     1  21294    0        0             0        0
# 309  310     939       0     0  22767    0        0             0        0
# 310  311     839       0     0  13879    0        0             0        0
# 311  312     788       0     1  12109    0        0             0        1
#
# ...

# %%
features = numeric_features + categorical_features
X = df[features].copy()
y = df[target].copy()


X = X.dropna()
y = y.loc[X.index]

print(f"Размер данных после предобработки: {X.shape}")
# Out:
# Размер данных после предобработки: (312, 16)

# %%
X = df.drop(target, axis=1)
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
y_pred_lr = lr.predict(X_test_scaled)
print("Linear R2:", r2_score(y_test, y_pred_lr))
# Out:
# Linear R2: 0.48605060284182366

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train_scaled, y_train)
y_pred_ridge = ridge.predict(X_test_scaled)
print("Ridge R2:", r2_score(y_test, y_pred_ridge))
# Out:
# Ridge R2: 0.4878272851472699

# %%
rf = RandomForestRegressor(n_estimators=200, max_depth=10, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print("Random Forest R2:", r2_score(y_test, y_pred_rf))
# Out:
# Random Forest R2: 0.5005281310849455

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_test["Cholesterol"], y_test, alpha=0.5, label="True")
plt.scatter(X_test["Cholesterol"], y_pred_rf, alpha=0.5, label="Predicted")
plt.xlabel("Cholesterol")
plt.ylabel("target")
plt.legend()
plt.show()
